# %% [markdown]
# # ETL Processes
# Use this notebook to develop the ETL process for each of your tables before completing the `etl.py` file to load the whole datasets.

# %%
import os
import glob
import psycopg2
import pandas as pd
from sql_queries import *

# %%
conn = psycopg2.connect("host=127.0.0.1 dbname=sparkifydb user=student password=student")
cur = conn.cursor()

# %%
def get_files(filepath):
    all_files = []
    for root, dirs, files in os.walk(filepath):
        files = glob.glob(os.path.join(root,'*.json'))
        for f in files :
            all_files.append(os.path.abspath(f))
    
    return all_files

# %% [markdown]
# # Process `song_data`
# In this first part, you'll perform ETL on the first dataset, `song_data`, to create the `songs` and `artists` dimensional tables.
#
# Let's perform ETL on a single song file and load a single record into each table to start.
# - Use the `get_files` function provided above to get a list of all song JSON files in `data/song_data`
# - Select the first song in this list
# - Read the song file and view the data

# %%
song_files = get_files(r'data/song_data/')
print(song_files[0])
# Out:
# /home/workspace/data/song_data/A/B/C/TRABCRU128F423F449.json

# %%
filepath = 'data/song_data'

# %%
df = pd.read_json(song_files[0], typ='series')
#df = ser.to_frame('count')
df.head()
# Out:
# num_songs                            1
# artist_id           AR8IEZO1187B99055E
# artist_latitude                   None
# artist_longitude                  None
# artist_location
# dtype: object

# %% [markdown]
# ## #1: `songs` Table
# #### Extract Data for Songs Table
# - Select columns for song ID, title, artist ID, year, and duration
# - Use `df.values` to select just the values from the dataframe
# - Index to select the first (only) record in the dataframe
# - Convert the array to a list and set it to `song_data`

# %%
song_data = df[['song_id','title','artist_id','year','duration']]
song_data
# Out:
# song_id      SOINLJW12A8C13314C
# title             City Slickers
# artist_id    AR8IEZO1187B99055E
# year                       2008
# duration                149.864
# dtype: object

# %% [markdown]
# #### Insert Record into Song Table
# Implement the `song_table_insert` query in `sql_queries.py` and run the cell below to insert a record for this song into the `songs` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `songs` table in the sparkify database.

# %%
cur.execute(song_table_insert, song_data)
conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added a record to this table.

# %% [markdown]
# ## #2: `artists` Table
# #### Extract Data for Artists Table
# - Select columns for artist ID, name, location, latitude, and longitude
# - Use `df.values` to select just the values from the dataframe
# - Index to select the first (only) record in the dataframe
# - Convert the array to a list and set it to `artist_data`

# %%
artist_data = df[['artist_id','artist_name','artist_location','artist_latitude','artist_longitude']]
artist_data
# Out:
# artist_id           AR8IEZO1187B99055E
# artist_name               Marc Shaiman
# artist_location
# artist_latitude                   None
# artist_longitude                  None
# dtype: object

# %% [markdown]
# #### Insert Record into Artist Table
# Implement the `artist_table_insert` query in `sql_queries.py` and run the cell below to insert a record for this song's artist into the `artists` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `artists` table in the sparkify database.

# %%
cur.execute(artist_table_insert, artist_data)
conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added a record to this table.

# %% [markdown]
# # Process `log_data`
# In this part, you'll perform ETL on the second dataset, `log_data`, to create the `time` and `users` dimensional tables, as well as the `songplays` fact table.
#
# Let's perform ETL on a single log file and load a single record into each table.
# - Use the `get_files` function provided above to get a list of all log JSON files in `data/log_data`
# - Select the first log file in this list
# - Read the log file and view the data

# %%
log_files = get_files(r'data/log_data/')
print(log_files[0])
# Out:
# /home/workspace/data/log_data/2018/11/2018-11-29-events.json

# %%
filepath = 'data/log_data/'

# %%
df = pd.read_json(log_files[0], lines=True)
date_time = pd.to_datetime(df['ts'], unit='ms')
year = date_time.dt.year
hour = date_time.dt.hour
day = date_time.dt.day
week = date_time.dt.week
month = date_time.dt.month
weekday = date_time.dt.weekday
df.head(1)
#df['date'] = pd.to_datetime(df['ts'], errors='coerce')
# Out:
#               artist       auth firstName gender  itemInSession lastName  \
# 0  Sydney Youngblood  Logged In     Jacob      M             53    Klein
#
#       length level                             location method      page  \
# 0  238.07955  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
#
#    registration  sessionId               song  status             ts  \
# 0  1.540558e+12        954  Ain't No Sunshine     200  1543449657796
#
#                                            userAgent userId
# 0  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     73

# %% [markdown]
# ## #3: `time` Table
# #### Extract Data for Time Table
# - Filter records by `NextSong` action
# - Convert the `ts` timestamp column to datetime
#   - Hint: the current timestamp is in milliseconds
# - Extract the timestamp, hour, day, week of year, month, year, and weekday from the `ts` column and set `time_data` to a list containing these values in order
#   - Hint: use pandas' [`dt` attribute](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.dt.html) to access easily datetimelike properties.
# - Specify labels for these columns and set to `column_labels`
# - Create a dataframe, `time_df,` containing the time data for this file by combining `column_labels` and `time_data` into a dictionary and converting this into a dataframe

# %%
df1 = df[['artist','auth']]
#df = 
#df.head()

# %%
#t = 
#t.head()

# %%
time_data = (hour, day, week, month, year)
column_labels = ("hour","day","week_of_year","month","year")
time_data = dict(zip(column_labels, time_data))

# %%
time_df = pd.DataFrame(time_data)
time_df['title'] = df['song']
time_df.head()
# Out:
#    hour  day  week_of_year  month  year  \
# 0     0   29            48     11  2018
# 1     0   29            48     11  2018
# 2     0   29            48     11  2018
# 3     0   29            48     11  2018
# 4     0   29            48     11  2018
#
#                                          title
# 0                            Ain't No Sunshine
# 1                   My Advice 2 You (Explicit)
# 2  My First Kiss (Feat. Ke$ha) [Album Version]
# 3                       The Girl and The Robot
# 4                                      Too Shy

# %% [markdown]
# #### Insert Records into Time Table
# Implement the `time_table_insert` query in `sql_queries.py` and run the cell below to insert records for the timestamps in this log file into the `time` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `time` table in the sparkify database.

# %%
for i, row in time_df.iterrows():
    cur.execute(time_table_insert, list(row))
    conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# ## #4: `users` Table
# #### Extract Data for Users Table
# - Select columns for user ID, first name, last name, gender and level and set to `user_df`

# %%
user_df = df[['userId','firstName','lastName','gender','level']]

# %% [markdown]
# #### Insert Records into Users Table
# Implement the `user_table_insert` query in `sql_queries.py` and run the cell below to insert records for the users in this log file into the `users` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `users` table in the sparkify database.

# %%
for i, row in user_df.iterrows():
    cur.execute(user_table_insert, row)
    conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# ## #5: `songplays` Table
# #### Extract Data and Songplays Table
# This one is a little more complicated since information from the songs table, artists table, and original log file are all needed for the `songplays` table. Since the log file does not specify an ID for either the song or the artist, you'll need to get the song ID and artist ID by querying the songs and artists tables to find matches based on song title, artist name, and song duration time.
# - Implement the `song_select` query in `sql_queries.py` to find the song ID and artist ID based on the title, artist name, and duration of a song.
# - Select the timestamp, user ID, level, song ID, artist ID, session ID, location, and user agent and set to `songplay_data`
#
# #### Insert Records into Songplays Table
# - Implement the `songplay_table_insert` query and run the cell below to insert records for the songplay actions in this log file into the `songplays` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `songplays` table in the sparkify database.

# %%
for index, row in df.iterrows():

    # get songid and artistid from song and artist tables
    cur.execute(song_select, (row.song, row.artist, row.length))
    results = cur.fetchone()
    print(results)
    
    if results:
        songid, artistid = results
    else:
        songid, artistid = None, None
    
    # insert songplay record
    songplay_data = (songid, artistid, row.ts, row.level, row.sessionId, row.location, row.userAgent)
    cur.execute(songplay_table_insert, songplay_data)
    conn.commit()
# Out:
# row.song is Ain't No Sunshine row is artist                                           Sydney Youngblood
# auth                                                     Logged In
# firstName                                                    Jacob
# gender                                                           M
# itemInSession                                                   53
# lastName                                                     Klein
# length                                                      238.08
# level                                                         paid
# location                       Tampa-St. Petersburg-Clearwater, FL
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54056e+12
# sessionId                                                      954
# song                                             Ain't No Sunshine
# status                                                         200
# ts                                                   1543449657796
# userAgent        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# userId                                                          73
# Name: 0, dtype: object
# None
# row.song is My Advice 2 You (Explicit) row is artist                                                  Gang Starr
# auth                                                     Logged In
# firstName                                                    Layla
# gender                                                           F
# itemInSession                                                   88
# lastName                                                   Griffin
# length                                                     151.928
# level                                                         paid
# location                              Lake Havasu City-Kingman, AZ
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54106e+12
# sessionId                                                      984
# song                                    My Advice 2 You (Explicit)
# status                                                         200
# ts                                                   1543449690796
# userAgent        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# userId                                                          24
# Name: 1, dtype: object
# None
# row.song is My First Kiss (Feat. Ke$ha) [Album Version] row is artist                                                       3OH!3
# auth                                                     Logged In
# firstName                                                    Layla
# gender                                                           F
# itemInSession                                                   89
# lastName                                                   Griffin
# length                                                     192.522
# level                                                         paid
# location                              Lake Havasu City-Kingman, AZ
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54106e+12
# sessionId                                                      984
# song                   My First Kiss (Feat. Ke$ha) [Album Version]
# status                                                         200
# ts                                                   1543449841796
# userAgent        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# userId                                                          24
# Name: 2, dtype: object
# None
# row.song is The Girl and The Robot row is artist                                                 RÃÂ¶yksopp
# auth                                                     Logged In
# firstName                                                    Jacob
# gender                                                           M
# itemInSession                                                   54
# lastName                                                     Klein
# length                                                     369.815
# level                                                         paid
# location                       Tampa-St. Petersburg-Clearwater, FL
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54056e+12
# sessionId                                                      954
# song                                        The Girl and The Robot
# status                                                         200
# ts                                                   1543449895796
# userAgent        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# userId                                                          73
# Name: 3, dtype: object
# None
# row.song is Too Shy row is artist                                                  Kajagoogoo
# auth                                                     Logged In
# firstName                                                    Layla
# gender                                                           F
# itemInSession                                                   90
# lastName                                                   Griffin
# length                                                     223.555
# level                                                         paid
# location                              Lake Havasu City-Kingman, AZ
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54106e+12
# sessionId                                                      984
# song                                                       Too Shy
# status                                                         200
# ts                                                   1543450033796
# userAgent        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# userId                                                          24
# Name: 4, dtype: object
# None
# row.song is Potential row is artist                                      The Jimmy Castor Bunch
# auth                                                     Logged In
# firstName                                                    Layla
# gender                                                           F
# itemInSession                                                   91
# lastName                                                   Griffin
# length                                                     306.546
# level                                                         paid
# location                              Lake Havasu City-Kingman, AZ
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54106e+12
# sessionId                                                      984
# song                                                     Potential
# status                                                         200
# ts                                                   1543450256796
# userAgent        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# userId                                                          24
# Name: 5, dtype: object
# None
# row.song is The Great Satan (What Would Satan Do Mix) row is artist                                                    Ministry
# auth                                                     Logged In
# firstName                                                    Jacob
# gender                                                           M
# itemInSession                                                   55
# lastName                                                     Klein
# length                                                     186.697
# level                                                         paid
# location                       Tampa-St. Petersburg-Clearwater, FL
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54056e+12
# sessionId                                                      954
# song                     The Great Satan (What Would Satan Do Mix)
# status                                                         200
# ts                                                   1543450264796
# userAgent        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# userId                                                          73
# Name: 6, dtype: object
# None
# row.song is The Screamer row is artist                                              Bouncing Souls
# auth                                                     Logged In
# firstName                                                    Jacob
# gender                                                           M
# itemInSession                                                   56
# lastName                                                     Klein
# length                                                     117.315
# level                                                         paid
# location                       Tampa-St. Petersburg-Clearwater, FL
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54056e+12
# sessionId                                                      954
# song                                                  The Screamer
# status                                                         200
# ts                                                   1543450450796
# userAgent        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# userId                                                          73
# Name: 7, dtype: object
# None
# row.song is Knife Going In (Album Version) row is artist                                              Tegan And Sara
# auth                                                     Logged In
# firstName                                                    Layla
# gender                                                           F
# itemInSession                                                   92
# lastName                                                   Griffin
# length                                                     129.671
# level                                                         paid
# location                              Lake Havasu City-Kingman, AZ
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54106e+12
# sessionId                                                      984
# song                                Knife Going In (Album Version)
# status                                                         200
# ts                                                   1543450562796
# userAgent        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# userId                                                          24
# Name: 8, dtype: object
# None
# row.song is The Greatest View (Album Version) row is artist                                                 Silverchair
# auth                                                     Logged In
# firstName                                                    Layla
# gender                                                           F
# itemInSession                                                   93
# lastName                                                   Griffin
# length                                                     242.964
# level                                                         paid
# location                              Lake Havasu City-Kingman, AZ
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54106e+12
# sessionId                                                      984
# song                             The Greatest View (Album Version)
# status                                                         200
# ts                                                   1543450691796
# userAgent        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# userId                                                          24
# Name: 9, dtype: object
# None
# row.song is T.N.T. For The Brain (112 Bpm) (Radio Edit) row is artist                                                      Enigma
# auth                                                     Logged In
# firstName                                                    Layla
# gender                                                           F
# itemInSession                                                   94
# lastName                                                   Griffin
# length                                                     242.782
# level                                                         paid
# location                              Lake Havasu City-Kingman, AZ
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54106e+12
# sessionId                                                      984
# song                   T.N.T. For The Brain (112 Bpm) (Radio Edit)
# status                                                         200
# ts                                                   1543450933796
# userAgent        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# userId                                                          24
# Name: 10, dtype: object
# None
# row.song is Mon MÃÂ©tro row is artist                                                        Anis
# auth                                                     Logged In
# firstName                                                    Layla
# gender                                                           F
# itemInSession                                                   95
# lastName                                                   Griffin
# length                                                     278.125
# level                                                         paid
# location                              Lake Havasu City-Kingman, AZ
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54106e+12
# sessionId                                                      984
# song                                                  Mon MÃÂ©tro
# status                                                         200
# ts                                                   1543451175796
# userAgent        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# userId                                                          24
# Name: 11, dtype: object
# None
# row.song is Fly Like An Eagle row is artist                                                        Seal
# auth                                                     Logged In
# firstName                                                    Layla
# gender                                                           F
# itemInSession                                                   96
# lastName                                                   Griffin
# length                                                     254.066
# level                                                         paid
# location                              Lake Havasu City-Kingman, AZ
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54106e+12
# sessionId                                                      984
# song                                             Fly Like An Eagle
# status                                                         200
# ts                                                   1543451453796
# userAgent        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# userId                                                          24
# Name: 12, dtype: object
# None
# row.song is Restless row is artist                                      UNKLE Feat. Josh Homme
# auth                                                     Logged In
# firstName                                                    Layla
# gender                                                           F
# itemInSession                                                   97
# lastName                                                   Griffin
# length                                                       307.2
# level                                                         paid
# location                              Lake Havasu City-Kingman, AZ
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54106e+12
# sessionId                                                      984
# song                                                      Restless
# status                                                         200
# ts                                                   1543451707796
# userAgent        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# userId                                                          24
# Name: 13, dtype: object
# None
# row.song is You're The One row is artist                                               Dwight Yoakam
# auth                                                     Logged In
# firstName                                                    Layla
# gender                                                           F
# itemInSession                                                   98
# lastName                                                   Griffin
# length                                                     239.307
# level                                                         paid
# location                              Lake Havasu City-Kingman, AZ
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54106e+12
# sessionId                                                      984
# song                                                You're The One
# status                                                         200
# ts                                                   1543452014796
# userAgent        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# userId                                                          24
# Name: 14, dtype: object
# None
# row.song is Blue row is artist                                                    Elastica
# auth                                                     Logged In
# firstName                                                    Layla
# gender                                                           F
# itemInSession                                                   99
# lastName                                                   Griffin
# length                                                     141.923
# level                                                         paid
# location                              Lake Havasu City-Kingman, AZ
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54106e+12
# sessionId                                                      984
# song                                                          Blue
# status                                                         200
# ts                                                   1543452253796
# userAgent        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# userId                                                          24
# Name: 15, dtype: object
# None
# row.song is Channel 10 row is artist                                            Capone-N-Noreaga
# auth                                                     Logged In
# firstName                                                    Layla
# gender                                                           F
# itemInSession                                                  100
# lastName                                                   Griffin
# length                                                     194.821
# level                                                         paid
# location                              Lake Havasu City-Kingman, AZ
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54106e+12
# sessionId                                                      984
# song                                                    Channel 10
# status                                                         200
# ts                                                   1543452394796
# userAgent        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# userId                                                          24
# Name: 16, dtype: object
# None
# row.song is The Oak Tree (Album Version) row is artist                                                  Morris Day
# auth                                                     Logged In
# firstName                                                    Layla
# gender                                                           F
# itemInSession                                                  101
# lastName                                                   Griffin
# length                                                     442.462
# level                                                         paid
# location                              Lake Havasu City-Kingman, AZ
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54106e+12
# sessionId                                                      984
# song                                  The Oak Tree (Album Version)
# status                                                         200
# ts                                                   1543452588796
# userAgent        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# userId                                                          24
# Name: 17, dtype: object
# None
# row.song is What If I Do? row is artist                                                Foo Fighters
# auth                                                     Logged In
# firstName                                                    Layla
# gender                                                           F
# itemInSession                                                  102
# lastName                                                   Griffin
# length                                                     302.915
# level                                                         paid
# location                              Lake Havasu City-Kingman, AZ
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54106e+12
# sessionId                                                      984
# song                                                 What If I Do?
# status                                                         200
# ts                                                   1543453030796
# userAgent        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# userId                                                          24
# Name: 18, dtype: object
# None
# row.song is You're Not Alone row is artist                                                       Olive
# auth                                                     Logged In
# firstName                                                    Layla
# gender                                                           F
# itemInSession                                                  103
# lastName                                                   Griffin
# length                                                     264.124
# level                                                         paid
# location                              Lake Havasu City-Kingman, AZ
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54106e+12
# sessionId                                                      984
# song                                              You're Not Alone
# status                                                         200
# ts                                                   1543453332796
# userAgent        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# userId                                                          24
# Name: 19, dtype: object
# None
# row.song is En Glad Calypso Om VÃÂ¥ren (Live '62) row is artist                                              Olle Adolphson
# auth                                                     Logged In
# firstName                                                    Layla
# gender                                                           F
# itemInSession                                                  104
# lastName                                                   Griffin
# length                                                     202.396
# level                                                         paid
# location                              Lake Havasu City-Kingman, AZ
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54106e+12
# sessionId                                                      984
# song                        En Glad Calypso Om VÃÂ¥ren (Live '62)
# status                                                         200
# ts                                                   1543453596796
# userAgent        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# userId                                                          24
# Name: 20, dtype: object
# None
# row.song is Down_ Down_ Down To Mehphisto's Cafe (Album Version) row is artist                                       Streetlight Manifesto
# auth                                                     Logged In
# firstName                                                      Ava
# gender                                                           F
# itemInSession                                                    0
# lastName                                                  Robinson
# length                                                     303.333
# level                                                         free
# location                                     New Haven-Milford, CT
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54093e+12
# sessionId                                                     1011
# song             Down_ Down_ Down To Mehphisto's Cafe (Album Ve...
# status                                                         200
# ts                                                   1543453763796
# userAgent        "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# userId                                                          50
# Name: 21, dtype: object
# None
# row.song is Tu Eres Ajena row is artist                                                 Frank Reyes
# auth                                                     Logged In
# firstName                                                    Layla
# gender                                                           F
# itemInSession                                                  105
# lastName                                                   Griffin
# length                                                     239.673
# level                                                         paid
# location                              Lake Havasu City-Kingman, AZ
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54106e+12
# sessionId                                                      984
# song                                                 Tu Eres Ajena
# status                                                         200
# ts                                                   1543453798796
# userAgent        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# userId                                                          24
# Name: 22, dtype: object
# None
# row.song is Estadio Azteca row is artist                                             Andres Calamaro
# auth                                                     Logged In
# firstName                                                    Layla
# gender                                                           F
# itemInSession                                                  106
# lastName                                                   Griffin
# length                                                     217.547
# level                                                         paid
# location                              Lake Havasu City-Kingman, AZ
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54106e+12
# sessionId                                                      984
# song                                                Estadio Azteca
# status                                                         200
# ts                                                   1543454037796
# userAgent        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# userId                                                          24
# Name: 23, dtype: object
# None
# row.song is Sleeper row is artist                                                      Zero 7
# auth                                                     Logged In
# firstName                                                    Layla
# gender                                                           F
# itemInSession                                                  107
# lastName                                                   Griffin
# length                                                     279.562
# level                                                         paid
# location                              Lake Havasu City-Kingman, AZ
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54106e+12
# sessionId                                                      984
# song                                                       Sleeper
# status                                                         200
# ts                                                   1543454254796
# userAgent        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# userId                                                          24
# Name: 24, dtype: object
# None
# row.song is Toxic row is artist                               Mark Ronson featuring Tiggers
# auth                                                     Logged In
# firstName                                                    Layla
# gender                                                           F
# itemInSession                                                  108
# lastName                                                   Griffin
# length                                                     245.185
# level                                                         paid
# location                              Lake Havasu City-Kingman, AZ
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54106e+12
# sessionId                                                      984
# song                                                         Toxic
# status                                                         200
# ts                                                   1543454533796
# userAgent        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# userId                                                          24
# Name: 25, dtype: object
# None
# row.song is Merry Go Round (Remastered Single Version) row is artist                                                 Keith Sweat
# auth                                                     Logged In
# firstName                                                    Layla
# gender                                                           F
# itemInSession                                                  109
# lastName                                                   Griffin
# length                                                     295.784
# level                                                         paid
# location                              Lake Havasu City-Kingman, AZ
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54106e+12
# sessionId                                                      984
# song                    Merry Go Round (Remastered Single Version)
# status                                                         200
# ts                                                   1543454778796
# userAgent        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# userId                                                          24
# Name: 26, dtype: object
# None
# row.song is Square Peg Round Hole row is artist                                                Wakey!Wakey!
# auth                                                     Logged In
# firstName                                                    Layla
# gender                                                           F
# itemInSession                                                  110
# lastName                                                   Griffin
# length                                                     145.031
# level                                                         paid
# location                              Lake Havasu City-Kingman, AZ
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54106e+12
# sessionId                                                      984
# song                                         Square Peg Round Hole
# status                                                         200
# ts                                                   1543455073796
# userAgent        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# userId                                                          24
# Name: 27, dtype: object
# None
# row.song is Eqypt row is artist                                         The Mercury Program
# auth                                                     Logged In
# firstName                                                    Layla
# gender                                                           F
# itemInSession                                                  111
# lastName                                                   Griffin
# length                                                     292.362
# level                                                         paid
# location                              Lake Havasu City-Kingman, AZ
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54106e+12
# sessionId                                                      984
# song                                                         Eqypt
# status                                                         200
# ts                                                   1543455218796
# userAgent        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# userId                                                          24
# Name: 28, dtype: object
# None
# row.song is Make Her Say row is artist                              Kid Cudi / Kanye West / Common
# auth                                                     Logged In
# firstName                                                    Layla
# gender                                                           F
# itemInSession                                                  112
# lastName                                                   Griffin
# length                                                     237.766
# level                                                         paid
# location                              Lake Havasu City-Kingman, AZ
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54106e+12
# sessionId                                                      984
# song                                                  Make Her Say
# status                                                         200
# ts                                                   1543455510796
# userAgent        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# userId                                                          24
# Name: 29, dtype: object
# None
# row.song is Nice Day For A Resurrection row is artist                                                 Nekromantix
# auth                                                     Logged In
# firstName                                                    Layla
# gender                                                           F
# itemInSession                                                  113
# lastName                                                   Griffin
# length                                                     263.105
# level                                                         paid
# location                              Lake Havasu City-Kingman, AZ
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54106e+12
# sessionId                                                      984
# song                                   Nice Day For A Resurrection
# status                                                         200
# ts                                                   1543455747796
# userAgent        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# userId                                                          24
# Name: 30, dtype: object
# None
# row.song is None row is artist                                                        None
# auth                                                     Logged In
# firstName                                                    Layla
# gender                                                           F
# itemInSession                                                  114
# lastName                                                   Griffin
# length                                                         NaN
# level                                                         paid
# location                              Lake Havasu City-Kingman, AZ
# method                                                         GET
# page                                                          Home
# registration                                           1.54106e+12
# sessionId                                                      984
# song                                                          None
# status                                                         200
# ts                                                   1543455764796
# userAgent        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# userId                                                          24
# Name: 31, dtype: object
# None
# row.song is Sinisten tÃÂ¤htien alla row is artist                               J. Karjalainen & Mustat Lasit
# auth                                                     Logged In
# firstName                                                    Layla
# gender                                                           F
# itemInSession                                                  115
# lastName                                                   Griffin
# length                                                     336.744
# level                                                         paid
# location                              Lake Havasu City-Kingman, AZ
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54106e+12
# sessionId                                                      984
# song                                      Sinisten tÃÂ¤htien alla
# status                                                         200
# ts                                                   1543456010796
# userAgent        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# userId                                                          24
# Name: 32, dtype: object
# None
# row.song is Wade Through The Night row is artist                                                  Matt Wertz
# auth                                                     Logged In
# firstName                                                    Layla
# gender                                                           F
# itemInSession                                                  116
# lastName                                                   Griffin
# length                                                      171.18
# level                                                         paid
# location                              Lake Havasu City-Kingman, AZ
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54106e+12
# sessionId                                                      984
# song                                        Wade Through The Night
# status                                                         200
# ts                                                   1543456346796
# userAgent        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# userId                                                          24
# Name: 33, dtype: object
# None
# row.song is My Axe row is artist                                          Insane Clown Posse
# auth                                                     Logged In
# firstName                                                    Layla
# gender                                                           F
# itemInSession                                                  117
# lastName                                                   Griffin
# length                                                     233.822
# level                                                         paid
# location                              Lake Havasu City-Kingman, AZ
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54106e+12
# sessionId                                                      984
# song                                                        My Axe
# status                                                         200
# ts                                                   1543456517796
# userAgent        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# userId                                                          24
# Name: 34, dtype: object
# None
# row.song is It's Only Money row is artist                                                  Thin Lizzy
# auth                                                     Logged In
# firstName                                                    Kaleb
# gender                                                           M
# itemInSession                                                    0
# lastName                                                      Cook
# length                                                     214.595
# level                                                         free
# location                                             Yuba City, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54068e+12
# sessionId                                                      951
# song                                               It's Only Money
# status                                                         200
# ts                                                   1543458271796
# userAgent        Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) G...
# userId                                                          54
# Name: 35, dtype: object
# None
# row.song is Untrust us row is artist                                             Crystal Castles
# auth                                                     Logged In
# firstName                                                    Kaleb
# gender                                                           M
# itemInSession                                                    1
# lastName                                                      Cook
# length                                                     186.383
# level                                                         free
# location                                             Yuba City, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54068e+12
# sessionId                                                      951
# song                                                    Untrust us
# status                                                         200
# ts                                                   1543458485796
# userAgent        Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) G...
# userId                                                          54
# Name: 36, dtype: object
# None
# row.song is Full Throttle row is artist                                                 The Prodigy
# auth                                                     Logged In
# firstName                                                    Kaleb
# gender                                                           M
# itemInSession                                                    2
# lastName                                                      Cook
# length                                                     302.602
# level                                                         free
# location                                             Yuba City, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54068e+12
# ...
# location                               Portland-South Portland, ME
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54079e+12
# sessionId                                                     1065
# song                                                     Good Time
# status                                                         200
# ts                                                   1543530769796
# userAgent        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# userId                                                          80
# Name: 353, dtype: object
# None
# row.song is Figures row is artist                                       The Whitest Boy Alive
# auth                                                     Logged In
# firstName                                                    Tegan
# gender                                                           F
# itemInSession                                                   31
# lastName                                                    Levine
# length                                                     234.579
# level                                                         paid
# location                               Portland-South Portland, ME
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54079e+12
# sessionId                                                     1065
# song                                                       Figures
# status                                                         200
# ts                                                   1543530944796
# userAgent        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# userId                                                          80
# Name: 354, dtype: object
# None
# row.song is Bone Broke row is artist                                           The White Stripes
# auth                                                     Logged In
# firstName                                                    Tegan
# gender                                                           F
# itemInSession                                                   32
# lastName                                                    Levine
# length                                                     194.481
# level                                                         paid
# location                               Portland-South Portland, ME
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54079e+12
# sessionId                                                     1065
# song                                                    Bone Broke
# status                                                         200
# ts                                                   1543531178796
# userAgent        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# userId                                                          80
# Name: 355, dtype: object
# None
# row.song is Are You The Walrus? row is artist                                                 Furthermore
# auth                                                     Logged In
# firstName                                                    Tegan
# gender                                                           F
# itemInSession                                                   33
# lastName                                                    Levine
# length                                                     211.696
# level                                                         paid
# location                               Portland-South Portland, ME
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54079e+12
# sessionId                                                     1065
# song                                           Are You The Walrus?
# status                                                         200
# ts                                                   1543531372796
# userAgent        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# userId                                                          80
# Name: 356, dtype: object
# None
# row.song is Amityville row is artist                                            Eminem / Bizarre
# auth                                                     Logged In
# firstName                                                    Tegan
# gender                                                           F
# itemInSession                                                   34
# lastName                                                    Levine
# length                                                     244.558
# level                                                         paid
# location                               Portland-South Portland, ME
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54079e+12
# sessionId                                                     1065
# song                                                    Amityville
# status                                                         200
# ts                                                   1543531583796
# userAgent        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# userId                                                          80
# Name: 357, dtype: object
# None
# row.song is I'm Not Calling You A Liar row is artist                                      Florence + The Machine
# auth                                                     Logged In
# firstName                                                    Tegan
# gender                                                           F
# itemInSession                                                   35
# lastName                                                    Levine
# length                                                     185.312
# level                                                         paid
# location                               Portland-South Portland, ME
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54079e+12
# sessionId                                                     1065
# song                                    I'm Not Calling You A Liar
# status                                                         200
# ts                                                   1543531827796
# userAgent        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# userId                                                          80
# Name: 358, dtype: object
# None
# row.song is Signos row is artist                                                 Soda Stereo
# auth                                                     Logged In
# firstName                                                   Braden
# gender                                                           M
# itemInSession                                                    0
# lastName                                                    Parker
# length                                                     316.734
# level                                                         free
# location                         Youngstown-Warren-Boardman, OH-PA
# method                                                         PUT
# page                                                      NextSong
# registration                                             1.541e+12
# sessionId                                                     1007
# song                                                        Signos
# status                                                         200
# ts                                                   1543531878796
# userAgent        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# userId                                                          74
# Name: 359, dtype: object
# None
# row.song is You Belong With Me row is artist                                                Taylor Swift
# auth                                                     Logged In
# firstName                                                    Tegan
# gender                                                           F
# itemInSession                                                   36
# lastName                                                    Levine
# length                                                     230.478
# level                                                         paid
# location                               Portland-South Portland, ME
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54079e+12
# sessionId                                                     1065
# song                                            You Belong With Me
# status                                                         200
# ts                                                   1543532012796
# userAgent        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# userId                                                          80
# Name: 360, dtype: object
# None
# row.song is None row is artist                                                        None
# auth                                                     Logged In
# firstName                                                    Tegan
# gender                                                           F
# itemInSession                                                   37
# lastName                                                    Levine
# length                                                         NaN
# level                                                         paid
# location                               Portland-South Portland, ME
# method                                                         GET
# page                                                          Home
# registration                                           1.54079e+12
# sessionId                                                     1065
# song                                                          None
# status                                                         200
# ts                                                   1543532195796
# userAgent        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# userId                                                          80
# Name: 361, dtype: object
# None
# row.song is Rearviewmirror row is artist                                                   Pearl Jam
# auth                                                     Logged In
# firstName                                                    Tegan
# gender                                                           F
# itemInSession                                                   38
# lastName                                                    Levine
# length                                                     283.898
# level                                                         paid
# location                               Portland-South Portland, ME
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54079e+12
# sessionId                                                     1065
# song                                                Rearviewmirror
# status                                                         200
# ts                                                   1543532242796
# userAgent        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# userId                                                          80
# Name: 362, dtype: object
# None
# row.song is Me So Horny row is artist                                             The 2 Live Crew
# auth                                                     Logged In
# firstName                                                    Tegan
# gender                                                           F
# itemInSession                                                   39
# lastName                                                    Levine
# length                                                     188.316
# level                                                         paid
# location                               Portland-South Portland, ME
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54079e+12
# sessionId                                                     1065
# song                                                   Me So Horny
# status                                                         200
# ts                                                   1543532525796
# userAgent        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# userId                                                          80
# Name: 363, dtype: object
# None
# row.song is Loco row is artist                                                         311
# auth                                                     Logged In
# firstName                                                    Tegan
# gender                                                           F
# itemInSession                                                   40
# lastName                                                    Levine
# length                                                     113.266
# level                                                         paid
# location                               Portland-South Portland, ME
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54079e+12
# sessionId                                                     1065
# song                                                          Loco
# status                                                         200
# ts                                                   1543532713796
# userAgent        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# userId                                                          80
# Name: 364, dtype: object
# None
# row.song is Midnight Groovin' (7" Version) (2006 Digital Remaster) row is artist                                          Light Of The World
# auth                                                     Logged In
# firstName                                                  Kynnedi
# gender                                                           F
# itemInSession                                                    0
# lastName                                                   Sanchez
# length                                                     207.072
# level                                                         free
# location                                          Cedar Rapids, IA
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54108e+12
# sessionId                                                     1029
# song             Midnight Groovin' (7" Version) (2006 Digital R...
# status                                                         200
# ts                                                   1543533515796
# userAgent        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_5...
# userId                                                          89
# Name: 365, dtype: object
# None

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# # Close Connection to Sparkify Database

# %%
conn.close()

# %% [markdown]
# # Implement `etl.py`
# Use what you've completed in this notebook to implement `etl.py`.
